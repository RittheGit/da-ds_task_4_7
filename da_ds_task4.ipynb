# %% [markdown]
# Even or Odd Checker
#
# -	Task: Write a program that prompts the user for an integer.
#   -	Use if/else to check whether the number is even or odd.
#   -	Print "Even" or "Odd" accordingly.

# %%
number = int(input("Enter an interger: "))
if number % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter an interger: 1
# Odd number

# %%
def check_number(number):
  if number % 2 == 0:
    return "The number is even number"
  else:
    return "Ther number is odd number"

number = int(input("Enter an integer: "))
print(check_number(number))
# Out:
# Enter an integer: 1
# Ther number is odd number

# %% [markdown]
# Positive, Negative, or Zero
#
# -	Task: Write a program that prompts the user for a number.
#   -	Use if/elif/else to determine if the number is positive, negative, or zero.
#   -	Print a message such as "The number is positive.".

# %%
number = int(input("Enter an integer: "))
if number > 0:
    print('The number is positive.')
elif number < 0:
    print('The number is negative.')
else:
    print('The number is zero')
# Out:
# Enter an integer: 1
# The number is positive.

# %%
def check_number(number):
  if number > 0:
    return "The number is positive"
  elif number < 0:
    return "The number is negative"
  else:
    return "The number is zero"

number = int(input("Enter an integer: "))
print(check_number(number))
# Out:
# Enter an integer: 1
# The number is positive

# %% [markdown]
# Grade Categorizer
#
# -	Task: Prompt the user for a number between 0 and 100 (the score).
#   -	Use if/elif/else to categorize the score:
#     -	90–100: "Grade A"
#     - 80–89: "Grade B"
#     -	70–79: "Grade C"
#     -	< 70: "Fail"

# %%
score = int(input("Enter score(0-100): ")) # nested loop
if score <  0 or score > 100:
  print('Invalid score')
else:
  if score >= 90:
    print("Grade A")
  elif score >= 80:
    print("Grade B")
  elif score >= 70:
    print("Grade C")
  else:
    print("Fail")
# Out:
# Enter score(0-100): 1
# Fail

# %%
score = int(input("Enter score(0-100): ")) # if elif else, but if number is less than 0 or more than 100 shows fail result.

if score >= 90 and score <= 100:
  print("Grade A")
elif score >= 80 and score <= 89:
  print("Grade B")
elif score >= 70 and score <= 79:
  print("Grade C")
else:
  print("Fail")
# Out:
# Enter score(0-100): 1
# Fail

# %%
def your_score(score): # def function for practice, not necessary for this kind of problem.
  if score < 0 or score > 100:
    return "Invalid number"
  else:
    if score >= 90:
      return "Grade A"
    elif score >= 80:
      return "Grade B"
    elif score >= 70:
      return "Grade c"
    else:
      return "Fail"

score = int(input("Enter your score: "))
print(your_score(score))
# Out:
# Enter your score: 1
# Fail

# %% [markdown]
# Multiples of 3 and 5
#
# -	Task: Prompt the user for a single integer n.
#   -	Use a for loop to iterate from 1 up to n (inclusive).
#   -	For each value i, print:
#     -	"Multiple of both" if i is divisible by 3 and 5.
#     - "Multiple of 3" if i is divisible by 3 but not 5.
#     -	"Multiple of 5" if i is divisible by 5 but not 3.
#     -	The number i itself otherwise.

# %%
n = int(input("Enter a single integer: "))

for i in range(1, n + 1):
  if i  % 3 == 0 and i % 5 == 0:
    print("Multiple of both")
  elif i % 3 == 0 and i % 5 != 0:
    print("Multiple of 3")
  elif i % 3 != 0 and i % 5 == 0:
    print("Multiple of 5")
  else:
    print("Not multiple of both")
# Out:
# Enter a single integer: 1
# Not multiple of both

# %% [markdown]
# Simple Password Check
#
# -	Task: Prompt the user for a password (e.g., "secret").
#   -	Use if to check if the user’s input matches the correct password.
#   -	If correct, print "Access granted", otherwise print "Access denied".

# %%
password = str(input("Enter a password: "))
if password == "secret":
  print('Access granted')
else:
  print("Access denied")
# Out:
# Enter a password: pass
# Access denied

# %% [markdown]
# Count Vowels in a String
#
# -	Task: Ask the user for a string.
#     -	Use a for loop to iterate over each character.
#     -	Use if conditions to check if it’s a vowel ("a", "e", "i", "o", "u").
#     -	Count the total number of vowels and print the result.

# %%
text = str(input("Enter a word: "))
count = 0

for char in text: # go through all the character in text
  if char in "aeiouAEIOU": # if the character has any vowel count and add.
    count += 1

print("Total vowels:", count)
# Out:
# Enter a word: interstellar
# Total vowels: 4

# %% [markdown]
# Smallest of Three Numbers
#
# -	Task: Prompt the user for three different numbers.
#     -	Use if/elif/else to find and print which one is smallest.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 <= num2 and num1 <= num3:
  print(num1, 'is the smallest')
elif num2 <= num1 and num2 <=num3:
  print(num2, 'is the smallest')
else:
  print(num3, "is the smallest")
# Out:
# Enter first number: 9
# Enter second number: 3
# Enter third number: 10
# 3.0 is the smallest

# %% [markdown]
# Simple Menu Selection
#
# -	Task: Prompt the user to choose an option (e.g., 1 for "Start", 2 for "Settings", 3 for "Exit").
#   -	Use if/elif/else to print a response based on which option is chosen.
#   -	Example:
#     -	If user enters 1: print "Game starting..."
#     -	If user enters 2: print "Opening settings..."
#     -	If user enters 3 or any other: print "Exiting..."

# %%
print("1. Start")
print("2. Setting")
print("3. Exit")

choice = int(input("Choose an option: "))

if choice == 1:
  print("Game starting...")
elif choice == 2:
  print("Opening settings...")
else:
  print("Exiting")
# Out:
# 1. Start
# 2. Setting
# 3. Exit
# Choose an option: 4
# Exiting
